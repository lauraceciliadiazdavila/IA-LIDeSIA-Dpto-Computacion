# %% [markdown]
# <a href="https://colab.research.google.com/github/lauraceciliadiazdavila/IA-2023/blob/main/11.RNN/RNN_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # RNN
# ---
#
#
# FCEFyN - UNC - Cátedra de Inteligencia Artificial

# %% [markdown]
# ---
#
# *   Autor/es: Ing. Facundo Nieto (LIDeSIA - FCEFyN)
#
# *   Directora: Dra. Laura Cecilia Diaz Davila (LIDeSIA - FCEFyN)
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1 Crear secuencia

# %% [markdown]
# ## 1.1 Señal

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:
      for series_num in series:
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      plt.plot(time[start:end], series[start:end], format)

    plt.xlabel("Time")
    plt.ylabel("Valor")
    plt.grid(True)
    plt.show()

def trend(time, slope=0):
    series = slope * time
    return series

def seasonal_pattern(season_time):
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    season_time = ((time + phase) % period) / period
    data_pattern = amplitude * seasonal_pattern(season_time)
    return data_pattern

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    noise = rnd.randn(len(time)) * noise_level
    return noise

# %%
# Modificar parametros para cambiar la morfologia de la serie temporal
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 80
slope = 0.05
noise_level = 2

# Crear la serie
series = baseline + trend(time, slope) + seasonality(time, period=200, amplitude=amplitude)

# Agregar ruido
series += noise(time, noise_level, seed=50)

# Graficar la serie
plot_series(time, series)

# %%
#Separar datos de TRAIN y TEST

# muestra en la que se realiza el recorte
split_time = 1000

time_train = time[:split_time]
x_train = series[:split_time]

time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
# Graficar la data de entrenamiento
plot_series(time_train, x_train)

# %%
# Graficar la data de validación
plot_series(time_valid, x_valid)

# %% [markdown]
# ## 1.2 Ventanear

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):

    dataset = tf.data.Dataset.from_tensor_slices(series) # Generamos un dataset de TF
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %%
# Definir parametros
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# # 2 Enfoque no secuencial

# %% [markdown]
# ## 2.1 DNN

# %%
# Definir modelos
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(10, input_shape=[window_size], activation='relu'),
                                    tf.keras.layers.Dense(1)])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                210
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilar y entrenar !!
model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6, momentum=0.9))
model.fit(dataset,epochs=100)

# https://www.tensorflow.org/api_docs/python/tf/keras/losses/MeanSquaredError
# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD
# Out:
# Epoch 1/100
# 31/31 [==============================] - 0s 2ms/step - loss: 3838.1897
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 343.5903
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 226.3224
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 195.0039
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 177.8156
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 167.1838
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 157.1629
# Epoch 8/100
# 31/31 [==============================] - 0s 1ms/step - loss: 149.8557
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 142.9762
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 137.1402
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 131.9607
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 127.0650
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 123.2090
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 120.0888
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 117.4258
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 115.0921
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 111.3701
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 110.0225
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 108.1628
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 106.1481
# Epoch 21/100
# 31/31 [==============================] - 0s 1ms/step - loss: 103.7545
# Epoch 22/100
# 31/31 [==============================] - 0s 1ms/step - loss: 102.1712
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 101.6753
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 99.6300
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 98.5887
# Epoch 26/100
# 31/31 [==============================] - 0s 1ms/step - loss: 98.4702
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 96.0414
# Epoch 28/100
# 31/31 [==============================] - 0s 2ms/step - loss: 95.4954
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 94.5748
# Epoch 30/100
# 31/31 [==============================] - 0s 1ms/step - loss: 93.7159
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 93.7042
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 92.7989
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 92.1074
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 91.8784
# Epoch 35/100
# 31/31 [==============================] - 0s 1ms/step - loss: 90.9496
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 90.5784
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 90.4078
# Epoch 38/100
# 31/31 [==============================] - 0s 1ms/step - loss: 89.2015
# Epoch 39/100
# 31/31 [==============================] - 0s 1ms/step - loss: 88.6801
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 88.4182
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 87.7008
# Epoch 42/100
# 31/31 [==============================] - 0s 1ms/step - loss: 87.3949
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 87.6259
# Epoch 44/100
# 31/31 [==============================] - 0s 1ms/step - loss: 87.2401
# Epoch 45/100
# 31/31 [==============================] - 0s 1ms/step - loss: 86.4178
# Epoch 46/100
# 31/31 [==============================] - 0s 1ms/step - loss: 86.9113
# Epoch 47/100
# 31/31 [==============================] - 0s 1ms/step - loss: 85.9436
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 85.3670
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 85.5624
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 84.6757
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 84.2605
# Epoch 52/100
# 31/31 [==============================] - 0s 1ms/step - loss: 84.9041
# Epoch 53/100
# 31/31 [==============================] - 0s 1ms/step - loss: 83.9335
# Epoch 54/100
# 31/31 [==============================] - 0s 1ms/step - loss: 83.5242
# Epoch 55/100
# 31/31 [==============================] - 0s 1ms/step - loss: 83.5770
# Epoch 56/100
# 31/31 [==============================] - 0s 1ms/step - loss: 82.9487
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 82.9777
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 82.7856
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 83.2792
# Epoch 60/100
# 31/31 [==============================] - 0s 2ms/step - loss: 82.2882
# Epoch 61/100
# 31/31 [==============================] - 0s 2ms/step - loss: 81.6279
# Epoch 62/100
# 31/31 [==============================] - 0s 1ms/step - loss: 82.0442
# Epoch 63/100
# 31/31 [==============================] - 0s 1ms/step - loss: 82.2486
# Epoch 64/100
# 31/31 [==============================] - 0s 1ms/step - loss: 81.5470
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.9899
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.7284
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.6532
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.8280
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.5726
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.1192
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.9963
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.9743
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.9239
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 80.1214
# Epoch 75/100
# 31/31 [==============================] - 0s 2ms/step - loss: 80.4583
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.6738
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.8163
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.9481
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.6148
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.0930
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.3950
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 79.2300
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.4311
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.0021
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.0792
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.8915
# Epoch 87/100
# 31/31 [==============================] - 0s 2ms/step - loss: 77.8188
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.9820
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 78.0085
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.7422
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.7877
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.3350
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.1705
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.4520
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.6119
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 76.6747
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 76.8457
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 77.2150
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 76.4512
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 76.5322

# %%
#Vamos a predecir y almacenar la predicciones en ORDEN
forecast = []

for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time - window_size:]
# Out:
# length of the forecast list: 461
# shape of the validation set: (461,)

# %%
# Graficar serie + predicción
results = np.array(forecast).squeeze() #disminuimos dimensión
plot_series(time_valid, (x_valid, results))
# Out:
# shape after converting to numpy array: (461, 1, 1)
# shape after squeezing: (461,)

# %%
# Metricas
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 86.10262
# 3.7765298

# %% [markdown]
# ## 2.2 Random forest

# %%
# TAREA

# %% [markdown]
# # 3 RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definir el modelo
model = tf.keras.models.Sequential([
  tf.keras.layers.SimpleRNN(40, return_sequences=False,input_shape=[None,1]),
  tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),optimizer=optimizer,
              metrics=["mae"])

# ENTRENAR
history = model.fit(dataset,epochs=100)

# https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD (Gradient descent (with momentum) optimizer)
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/Huber
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 4ms/step - loss: 52.0341 - mae: 52.5338
# Epoch 2/100
# 31/31 [==============================] - 0s 5ms/step - loss: 50.6095 - mae: 51.1094
# Epoch 3/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.8832 - mae: 49.3822
# Epoch 4/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.3879 - mae: 47.8866
# Epoch 5/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.2307 - mae: 46.7291
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 45.0874 - mae: 45.5860
# Epoch 7/100
# 31/31 [==============================] - 0s 4ms/step - loss: 43.9529 - mae: 44.4520
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 42.8365 - mae: 43.3345
# Epoch 9/100
# 31/31 [==============================] - 0s 4ms/step - loss: 41.7311 - mae: 42.2301
# Epoch 10/100
# 31/31 [==============================] - 0s 4ms/step - loss: 40.6486 - mae: 41.1468
# Epoch 11/100
# 31/31 [==============================] - 0s 5ms/step - loss: 39.5911 - mae: 40.0884
# Epoch 12/100
# 31/31 [==============================] - 0s 4ms/step - loss: 38.5553 - mae: 39.0526
# Epoch 13/100
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5501 - mae: 38.0484
# Epoch 14/100
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5661 - mae: 37.0631
# Epoch 15/100
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5992 - mae: 36.0965
# Epoch 16/100
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6578 - mae: 35.1551
# Epoch 17/100
# 31/31 [==============================] - 0s 4ms/step - loss: 33.7424 - mae: 34.2416
# Epoch 18/100
# 31/31 [==============================] - 0s 4ms/step - loss: 32.8316 - mae: 33.3302
# Epoch 19/100
# 31/31 [==============================] - 0s 4ms/step - loss: 31.9366 - mae: 32.4339
# Epoch 20/100
# 31/31 [==============================] - 0s 4ms/step - loss: 31.0722 - mae: 31.5677
# Epoch 21/100
# 31/31 [==============================] - 0s 4ms/step - loss: 30.2492 - mae: 30.7449
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 29.4747 - mae: 29.9692
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 28.7433 - mae: 29.2392
# Epoch 24/100
# 31/31 [==============================] - 0s 4ms/step - loss: 28.0597 - mae: 28.5547
# Epoch 25/100
# 31/31 [==============================] - 0s 4ms/step - loss: 27.4132 - mae: 27.9073
# Epoch 26/100
# 31/31 [==============================] - 0s 5ms/step - loss: 26.8001 - mae: 27.2938
# Epoch 27/100
# 31/31 [==============================] - 0s 4ms/step - loss: 26.2121 - mae: 26.7079
# Epoch 28/100
# 31/31 [==============================] - 0s 4ms/step - loss: 25.6426 - mae: 26.1389
# Epoch 29/100
# 31/31 [==============================] - 0s 5ms/step - loss: 25.0788 - mae: 25.5749
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 24.5125 - mae: 25.0082
# Epoch 31/100
# 31/31 [==============================] - 0s 4ms/step - loss: 23.9772 - mae: 24.4731
# Epoch 32/100
# 31/31 [==============================] - 0s 4ms/step - loss: 23.4515 - mae: 23.9452
# Epoch 33/100
# 31/31 [==============================] - 0s 4ms/step - loss: 22.9440 - mae: 23.4364
# Epoch 34/100
# 31/31 [==============================] - 0s 4ms/step - loss: 22.4495 - mae: 22.9419
# Epoch 35/100
# 31/31 [==============================] - 0s 5ms/step - loss: 21.9676 - mae: 22.4596
# Epoch 36/100
# 31/31 [==============================] - 0s 4ms/step - loss: 21.5070 - mae: 21.9982
# Epoch 37/100
# 31/31 [==============================] - 0s 5ms/step - loss: 21.0290 - mae: 21.5213
# Epoch 38/100
# 31/31 [==============================] - 0s 4ms/step - loss: 20.5725 - mae: 21.0649
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 20.1335 - mae: 20.6232
# Epoch 40/100
# 31/31 [==============================] - 0s 4ms/step - loss: 19.6963 - mae: 20.1847
# Epoch 41/100
# 31/31 [==============================] - 0s 4ms/step - loss: 19.3009 - mae: 19.7917
# Epoch 42/100
# 31/31 [==============================] - 0s 4ms/step - loss: 18.8280 - mae: 19.3152
# Epoch 43/100
# 31/31 [==============================] - 0s 4ms/step - loss: 18.4077 - mae: 18.8948
# Epoch 44/100
# 31/31 [==============================] - 0s 5ms/step - loss: 18.0351 - mae: 18.5223
# Epoch 45/100
# 31/31 [==============================] - 0s 4ms/step - loss: 17.7129 - mae: 18.1997
# Epoch 46/100
# 31/31 [==============================] - 0s 4ms/step - loss: 17.1613 - mae: 17.6481
# Epoch 47/100
# 31/31 [==============================] - 0s 4ms/step - loss: 16.7310 - mae: 17.2131
# Epoch 48/100
# 31/31 [==============================] - 0s 4ms/step - loss: 16.3317 - mae: 16.8134
# Epoch 49/100
# 31/31 [==============================] - 0s 4ms/step - loss: 15.9836 - mae: 16.4678
# Epoch 50/100
# 31/31 [==============================] - 1s 11ms/step - loss: 15.5973 - mae: 16.0774
# Epoch 51/100
# 31/31 [==============================] - 0s 7ms/step - loss: 15.5117 - mae: 15.9957
# Epoch 52/100
# 31/31 [==============================] - 0s 7ms/step - loss: 14.9927 - mae: 15.4694
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 14.6268 - mae: 15.1069
# Epoch 54/100
# 31/31 [==============================] - 0s 4ms/step - loss: 14.3913 - mae: 14.8667
# Epoch 55/100
# 31/31 [==============================] - 0s 4ms/step - loss: 14.0987 - mae: 14.5783
# Epoch 56/100
# 31/31 [==============================] - 0s 5ms/step - loss: 13.9741 - mae: 14.4567
# Epoch 57/100
# 31/31 [==============================] - 0s 7ms/step - loss: 13.5940 - mae: 14.0715
# Epoch 58/100
# 31/31 [==============================] - 0s 6ms/step - loss: 13.3521 - mae: 13.8314
# Epoch 59/100
# 31/31 [==============================] - 1s 9ms/step - loss: 13.1091 - mae: 13.5895
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 12.9248 - mae: 13.4026
# Epoch 61/100
# 31/31 [==============================] - 1s 6ms/step - loss: 12.6640 - mae: 13.1394
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 12.6105 - mae: 13.0917
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 12.3286 - mae: 12.8051
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 12.1452 - mae: 12.6217
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 11.9333 - mae: 12.4117
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 11.6489 - mae: 12.1271
# Epoch 67/100
# 31/31 [==============================] - 0s 5ms/step - loss: 11.6417 - mae: 12.1223
# Epoch 68/100
# 31/31 [==============================] - 0s 5ms/step - loss: 11.4365 - mae: 11.9145
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 11.2988 - mae: 11.7752
# Epoch 70/100
# 31/31 [==============================] - 0s 5ms/step - loss: 11.0324 - mae: 11.5038
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 10.8074 - mae: 11.2814
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 10.6543 - mae: 11.1259
# Epoch 73/100
# 31/31 [==============================] - 0s 6ms/step - loss: 10.5781 - mae: 11.0490
# Epoch 74/100
# 31/31 [==============================] - 0s 5ms/step - loss: 10.3972 - mae: 10.8722
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 10.5165 - mae: 10.9933
# Epoch 76/100
# 31/31 [==============================] - 0s 4ms/step - loss: 10.1113 - mae: 10.5848
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 10.0689 - mae: 10.5422
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.9935 - mae: 10.4677
# Epoch 79/100
# 31/31 [==============================] - 0s 5ms/step - loss: 9.8149 - mae: 10.2829
# Epoch 80/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.6683 - mae: 10.1395
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.6564 - mae: 10.1293
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.6233 - mae: 10.1010
# Epoch 83/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.6649 - mae: 10.1355
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.7825 - mae: 10.2646
# Epoch 85/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.2293 - mae: 9.6997
# Epoch 86/100
# 31/31 [==============================] - 0s 5ms/step - loss: 9.1374 - mae: 9.6036
# Epoch 87/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.0952 - mae: 9.5650
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 9.0007 - mae: 9.4697
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.8210 - mae: 9.2890
# Epoch 90/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.7673 - mae: 9.2379
# Epoch 91/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.8293 - mae: 9.3047
# Epoch 92/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.8377 - mae: 9.3118
# Epoch 93/100
# 31/31 [==============================] - 0s 5ms/step - loss: 8.5410 - mae: 9.0116
# Epoch 94/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.5173 - mae: 8.9881
# Epoch 95/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.4290 - mae: 8.8936
# Epoch 96/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.3604 - mae: 8.8309
# Epoch 97/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.5456 - mae: 9.0181
# Epoch 98/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.6715 - mae: 9.1493
# Epoch 99/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.5546 - mae: 9.0309
# Epoch 100/100
# 31/31 [==============================] - 0s 4ms/step - loss: 8.4752 - mae: 8.9498

# %%
#Vamos a predecir y almacenar la predicciones en ORDEN
forecast = []

for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time - window_size:]

# %%
#PLOTEAR SEÑAL ORIGINAL Y PREDICCIÓN
results = np.array(forecast).squeeze() #bajamos la dimensión
plot_series(time_valid, (x_valid, results))

# %%
# Metricas
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 1474.238
# 28.450819

# %% [markdown]
# # 4 Deep RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definir el modelo
model = tf.keras.models.Sequential([
  tf.keras.layers.SimpleRNN(40, return_sequences=True,input_shape=[None,1]),
  tf.keras.layers.SimpleRNN(40, return_sequences=False),
  tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Entrenar
history = model.fit(dataset,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 4s 11ms/step - loss: 50.7351 - mae: 51.2349
# Epoch 2/100
# 31/31 [==============================] - 0s 11ms/step - loss: 50.1861 - mae: 50.6858
# Epoch 3/100
# 31/31 [==============================] - 0s 10ms/step - loss: 49.7818 - mae: 50.2812
# Epoch 4/100
# 31/31 [==============================] - 0s 10ms/step - loss: 49.3405 - mae: 49.8392
# Epoch 5/100
# 31/31 [==============================] - 0s 10ms/step - loss: 48.7400 - mae: 49.2379
# Epoch 6/100
# 31/31 [==============================] - 0s 12ms/step - loss: 48.1274 - mae: 48.6259
# Epoch 7/100
# 31/31 [==============================] - 0s 11ms/step - loss: 47
# Epoch 71/100
# 31/31 [==============================] - 0s 11ms/step - loss: 22.0846 - mae: 22.5793
# Epoch 72/100
# 31/31 [==============================] - 0s 11ms/step - loss: 22.0736 - mae: 22.5688
# Epoch 73/100
# 31/31 [==============================] - 0s 11ms/step - loss: 21.9518 - mae: 22.4478
# Epoch 74/100
# 31/31 [==============================] - 1s 13ms/step - loss: 21.8651 - mae: 22.3607
# Epoch 75/100
# 31/31 [==============================] - 0s 11ms/step - loss: 21.5568 - mae: 22.0521
# Epoch 76/100
# 31/31 [==============================] - 0s 11ms/step - loss: 21.1392 - mae: 21.6325
# Epoch 77/100
# 31/31 [==============================] - 1s 13ms/step - loss: 20.9671 - mae: 21.4603
# Epoch 78/100
# 31/31 [==============================] - 0s 11ms/step - loss: 20.7569 - mae: 21.2506
# Epoch 79/100
# 31/31 [==============================] - 0s 11ms/step - loss: 20.5072 - mae: 20.9990
# Epoch 80/100
# 31/31 [==============================] - 0s 11ms/step - loss: 20.2255 - mae: 20.7169
# Epoch 81/100
# 31/31 [==============================] - 1s 12ms/step - loss: 20.0036 - mae: 20.4963
# Epoch 82/100
# 31/31 [==============================] - 1s 14ms/step - loss: 19.9995 - mae: 20.4927
# Epoch 83/100
# 31/31 [==============================] - 0s 12ms/step - loss: 19.7811 - mae: 20.2769
# Epoch 84/100
# 31/31 [==============================] - 0s 11ms/step - loss: 19.7686 - mae: 20.2625
# Epoch 85/100
# 31/31 [==============================] - 0s 11ms/step - loss: 19.8921 - mae: 20.3867
# Epoch 86/100
# 31/31 [==============================] - 0s 12ms/step - loss: 19.4504 - mae: 19.9461
# Epoch 87/100
# 31/31 [==============================] - 0s 11ms/step - loss: 19.0680 - mae: 19.5606
# Epoch 88/100
# 31/31 [==============================] - 1s 13ms/step - loss: 18.7604 - mae: 19.2489
# Epoch 89/100
# 31/31 [==============================] - 0s 10ms/step - loss: 18.7121 - mae: 19.2043
# Epoch 90/100
# 31/31 [==============================] - 0s 11ms/step - loss: 18.4051 - mae: 18.8925
# Epoch 91/100
# 31/31 [==============================] - 1s 12ms/step - loss: 18.8172 - mae: 19.3072
# Epoch 92/100
# 31/31 [==============================] - 1s 14ms/step - loss: 19.3307 - mae: 19.8190
# Epoch 93/100
# 31/31 [==============================] - 0s 11ms/step - loss: 19.0131 - mae: 19.5022
# Epoch 94/100
# 31/31 [==============================] - 0s 10ms/step - loss: 18.7540 - mae: 19.2415
# Epoch 95/100
# 31/31 [==============================] - 1s 13ms/step - loss: 18.3955 - mae: 18.8817
# Epoch 96/100
# 31/31 [==============================] - 0s 10ms/step - loss: 18.2436 - mae: 18.7277
# Epoch 97/100
# 31/31 [==============================] - 0s 12ms/step - loss: 18.0871 - mae: 18.5746
# Epoch 98/100
# 31/31 [==============================] - 0s 11ms/step - loss: 17.9608 - mae: 18.4469
# Epoch 99/100
# 31/31 [==============================] - 1s 13ms/step - loss: 17.5566 - mae: 18.0369
# Epoch 100/100
# 31/31 [==============================] - 1s 12ms/step - loss: 17.5688 - mae: 18.0558

# %%
#Vamos a predecir y almacenar la predicciones en ORDEN
forecast = []

for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time - window_size:]

# %%
# Graficamos ambas señales

results = np.array(forecast).squeeze() #disminuimos dimensión
plot_series(time_valid, (x_valid, results))

# %%
# Metricas
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 2016.5492
# 36.311504

# %% [markdown]
# TAREA:
#
#
#
# *   Probar Random forest
# *   Mejorar metricas
# *   tip: Ver learning rate
